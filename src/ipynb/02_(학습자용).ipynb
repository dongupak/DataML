# %% [markdown]
# # **생능 출판사 "으뜸 데이터 분석과 머신러닝"(개정판) 교재의 소스 코드**
# ## *2장 데이터 분석을 위한 도구*
# ---
# * 출판사 : 생능 출판사( http://www.booksr.co.kr/ )
# * 저자 : 박동규, 강영민, 김병욱
# * 책의 소스코드 저장소 : https://github.com/dongupak/DataML
# * 안내 : 이 노트북은 책의 코드를 담고 있습니다.
# *  저작권 : 본 주피터 노트북 코드는 자유롭게 배포가능하지만 위의 출판사, 저서, 저자표기와 함께 배포해 주십시오.

# %% [markdown]
# ### 2.1 데이터 분석과 머신러닝을 위한 강력한 프로그래밍 언어 : 파이썬

# %%
animals = ['lion', 'tiger', 'cat', 'dog']
animals.sort()       # animals 리스트 내부 문자열을 알파벳 순으로 정렬
animals
# Out:
# ['cat', 'dog', 'lion', 'tiger']

# %%
animals.append('rabbit') # animals 리스트에 새 원소를 추가
animals
# Out:
# ['cat', 'dog', 'lion', 'tiger', 'rabbit']

# %%
animals.reverse()    # animals 리스트를 원래 원소의 역순으로 재배열
animals
# Out:
# ['rabbit', 'tiger', 'lion', 'dog', 'cat']

# %% [markdown]
# ### 2.2 모듈의 개념과 활용

# %%
def max2(a, b):
    if a > b:
        return a
    else:
        return b

max2(100, 200)
# Out:
# 200

# %%
import math # 수학 함수가 있는 모듈을 코드 안으로 가져온다

a = math.fabs(-10) # -10의 절대값을 구하는 함수
print('math.fabs(-10) :', a)
b = math.sin(math.pi/2.0) # sin() 90도를 구하는 함수(라디안 각도 사용)
print('math.sin(m.pi/2.0) :', b)
# Out:
# math.fabs(-10) : 10.0
# math.sin(m.pi/2.0) : 1.0

# %%
import random

random.randrange(1, 7) # 1에서 6까지 임의의 정수를 생성함
# Out:
# 4

# %% [markdown]
# ### 2.7 주피터 노트북의 여러가지 기능들

# %%
# 셀의 실행순서와 구문 오류를 확인하는 코드
print('Hello World)
# Out:
#   File "<ipython-input-8-a5bfb52791f4>", line 2
#     print('Hello World)
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
# 올바르게 동작하는 코드
print('Hello World')
# Out:
# Hello World

# %%
num = 100

# %%
num = num + 100
print(num)
# Out:
# 200

# %% [markdown]
# ### 2.10 IPython에서 제공하는 마법 명령어

# %%
a1 = 100
a2 = 200

# %%
a
# Out:
# 10.0

# %%
def sum2(a, b):
    ''' sum2() : 두 수의 합을 반환하는 함수'''
    return a + b

# %%
sum2?

# %%
import numpy as np
a = np.random.randn(1000, 1000)
# %timeit np.dot(a, a)
# Out:
# 63.9 ms ± 1.8 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ### 알아두면 편리한 고급 마크다운 기능과 명령 모드

# %% [markdown]
# [생능출판사](https://www.booksr.co.kr/)

# %% [markdown]
# 생능출판사(https://www.booksr.co.kr/)

# %% [markdown]
# <img src ='https://raw.githubusercontent.com/dongupak/DataML/main/prime_cat.png'>

# %% [markdown]
# ### 2.13 클라우드 환경의 개발은 코랩으로 편리하게

# %%
print('Hello Python!')
# Out:
# Hello Python!

# %%
print('Welcome to Data Science and Machine Learning!')
# Out:
# Welcome to Data Science and Machine Learning!

# %%
# !cat /etc/issue.net
# Out:
# Ubuntu 22.04.3 LTS

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0xffffffff
# cpu MHz		: 2200.218
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed bhi
# ...

# %% [markdown]
# ### 2.15 코랩 디스크 마운트하고 파일 올리기

# %%
# !pwd
# Out:
# /content

# %%
# !ls -l /content
# Out:
# total 4
# drwxr-xr-x 1 root root 4096 Aug 14 13:23 sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-25-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     131   )
#     132   if ephemeral:
# --> 133     _message.blocking_request(
#     134         'request_auth',
#     135         request={'authType': 'dfs_ephemeral'},
#
# ...

# %% [markdown]
# ### 2.16 코랩 디스크의 내용 확인하기

# %%
# !ls ./drive/MyDrive -la
# Out:
# total 463712
# drwx------ 2 root root      4096 Nov  2 02:09  00_논문
# drwx------ 2 root root      4096 Aug 22 22:02  01_저술
# drwx------ 2 root root      4096 Nov  6  2020  02_연구관련
# drwx------ 2 root root      4096 Aug 22 22:02  03_강의관련
# drwx------ 2 root root      4096 Nov  6  2020  04_창원대학교업무관련
# drwx------ 2 root root      4096 Nov  6  2020  05_세미나
# drwx------ 2 root root      4096 Nov  6  2020  06_Youtube_영상자료들
# drwx------ 2 root root      4096 Nov 18  2020  07_IVIS_MobileX_연구실
# drwx------ 2 root root      4096 Nov  6  2020  08_기타자료
# drwx------ 2 root root      4096 Nov  6  2020  09_개인자료_이력서_서명등
# drwx------ 2 root root      4096 Nov 16  2020  10_정보통신공학과자료
# drwx------ 2 root root      4096 Nov 19  2020  11.앱개발자료
# -rw------- 1 root root 122123242 Aug  6 07:46 '으뜸데이터과학_전체그림 (1).key'
# drwx------ 2 root root      4096 Feb 10  2021  2021_창식아뭐보노_영상목록
# -rw------- 1 root root     73930 Apr 21  2021  bag_cartoon.png
# -rw------- 1 root root   5622488 Sep 26 06:32  busan_sup.png
# ...

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img = mpimg.imread('./drive/MyDrive/prime_cat.png')
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-aadc58c8cb9f> in <cell line: 3>()
#       1 import matplotlib.image as mpimg
#       2 import matplotlib.pyplot as plt
# ----> 3 img = mpimg.imread('./drive/MyDrive/prime_cat.png')
#       4 plt.imshow(img)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in imread(fname, format)
#    1561             "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1562             )
# -> 1563     with img_open(fname) as image:
#    1564         return (_pil_png_to_float_array(image)
#    1565                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# /usr/local/lib/python3.10/dist-packages/PIL/ImageFile.py in __init__(self, fp, filename)
#     103         if is_path(fp):
#     104             # filename
# --> 105             self.fp = open(fp, "rb")
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-4d6ae031-0ac4-435f-860e-d74459d839bb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4d6ae031-0ac4-435f-860e-d74459d839bb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving vehicle_prod.csv to vehicle_prod.csv

# %%
import pandas as pd

df = pd.read_csv('./vehicle_prod.csv')
df.head(3)
# Out:
#   Unnamed: 0   2007   2008   2009   2010   2011
# 0      China   7.71   7.95  11.96  15.84  16.33
# 1         EU  19.02  17.71  15.00  16.70  17.48
# 2         US  10.47   8.45   5.58   7.60   8.40
